# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
df['sex'][df['day']== 'Sun']
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 186    Female
# 187      Male
# 188    Female
# 189      Male
# 190      Male
# Name: sex, Length: 76, dtype: category
# Categories (2, object): ['Male', 'Female']

# %%
df['sex'][df['smoker']=='Yes']
# Out:
# 56       Male
# 58       Male
# 60       Male
# 61       Male
# 62       Male
#         ...
# 234      Male
# 236      Male
# 237      Male
# 240    Female
# 241      Male
# Name: sex, Length: 93, dtype: category
# Categories (2, object): ['Male', 'Female']

# %%
df['size'].mean()
# Out:
# 2.569672131147541

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df = pd.read_csv('weather.csv')

# %%
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
li = [{'day' : '1/1/2017', 'temperature' : 32, 'windspeed' : 6, 'event' : 'Rain'},
      {'day' : '2/1/2017', 'temperature' : 35, 'windspeed' : 7, 'event' : 'Sunny'},
     {'day' : '3/1/2017', 'temperature' : 28, 'windspeed' : 2, 'event' : 'Snow'},
     {'day' : '4/1/2017', 'temperature' : 24, 'windspeed' : 7, 'event' : 'Snow'},
     {'day' : '5/1/2017', 'temperature' : 32, 'windspeed' : 4, 'event' : 'Rain'},
     {'day' : '6/1/2017', 'temperature' : 32, 'windspeed' : 2, 'event' : 'Sunny'}]

# %%
df = pd.DataFrame(li)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  2/1/2017           35          7  Sunny
# 2  3/1/2017           28          2   Snow
# 3  4/1/2017           24          7   Snow
# 4  5/1/2017           32          4   Rain
# 5  6/1/2017           32          2  Sunny

# %%
df['temperature'].mean()
# Out:
# 30.5

# %%
df['day'][df['event']=='Sunny']
# Out:
# 1    2/1/2017
# 5    6/1/2017
# Name: day, dtype: object

# %%
rows, columns = df.shape

# %%
rows
# Out:
# 6

# %%
columns
# Out:
# 4

# %%
df.tail()
# Out:
#         day  temperature  windspeed  event
# 1  2/1/2017           35          7  Sunny
# 2  3/1/2017           28          2   Snow
# 3  4/1/2017           24          7   Snow
# 4  5/1/2017           32          4   Rain
# 5  6/1/2017           32          2  Sunny

# %%
df.tail()
# Out:
#         day  temperature  windspeed  event
# 1  2/1/2017           35          7  Sunny
# 2  3/1/2017           28          2   Snow
# 3  4/1/2017           24          7   Snow
# 4  5/1/2017           32          4   Rain
# 5  6/1/2017           32          2  Sunny

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  2/1/2017           35          7  Sunny
# 2  3/1/2017           28          2   Snow
# 3  4/1/2017           24          7   Snow
# 4  5/1/2017           32          4   Rain
# 5  6/1/2017           32          2  Sunny

# %%
df.tail(1)
# Out:
#         day  temperature  windspeed  event
# 5  6/1/2017           32          2  Sunny

# %%
df.tail(2)
# Out:
#         day  temperature  windspeed  event
# 4  5/1/2017           32          4   Rain
# 5  6/1/2017           32          2  Sunny

# %%
df.tail(4)
# Out:
#         day  temperature  windspeed  event
# 2  3/1/2017           28          2   Snow
# 3  4/1/2017           24          7   Snow
# 4  5/1/2017           32          4   Rain
# 5  6/1/2017           32          2  Sunny

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  2/1/2017           35          7  Sunny
# 2  3/1/2017           28          2   Snow
# 3  4/1/2017           24          7   Snow
# 4  5/1/2017           32          4   Rain
# 5  6/1/2017           32          2  Sunny

# %%
df[2:4]
# Out:
#         day  temperature  windspeed event
# 2  3/1/2017           28          2  Snow
# 3  4/1/2017           24          7  Snow

# %%
df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  3/1/2017           28          2  Snow
# 3  4/1/2017           24          7  Snow
# 4  5/1/2017           32          4  Rain

# %%
df[:]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  2/1/2017           35          7  Sunny
# 2  3/1/2017           28          2   Snow
# 3  4/1/2017           24          7   Snow
# 4  5/1/2017           32          4   Rain
# 5  6/1/2017           32          2  Sunny

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.day
# Out:
# 0    1/1/2017
# 1    2/1/2017
# 2    3/1/2017
# 3    4/1/2017
# 4    5/1/2017
# 5    6/1/2017
# Name: day, dtype: object

# %%
type(df['event'])
# Out:
# pandas.core.series.Series

# %%
df[['day','windspeed']]
# Out:
#         day  windspeed
# 0  1/1/2017          6
# 1  2/1/2017          7
# 2  3/1/2017          2
# 3  4/1/2017          7
# 4  5/1/2017          4
# 5  6/1/2017          2

# %%
df['temperature'].std()
# Out:
# 3.8858718455450894

# %%
df['windspeed'].mean()
# Out:
# 4.666666666666667

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.500000   4.666667
# std       3.885872   2.338090
# min      24.000000   2.000000
# 25%      29.000000   2.500000
# 50%      32.000000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000
