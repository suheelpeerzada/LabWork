# %%
import pandas as pd
from sklearn import linear_model
import numpy as np
import matplotlib.pyplot as plt

# %%
data = [{'area':2600, 'price': 550000},{'area': 3000, 'price': 565000},{'area': 3200, 'price': 610000},{'area': 3600, 'price': 680000},{'area': 4000, 'price':725000}]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
df.plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price, color='red', marker='+')
plt.plot(df.area, reg.predict(df[['area']]), color = 'blue')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 plt.ylabel('price')
#       4 plt.scatter(df.area,df.price, color='red', marker='+')
# ----> 5 plt.plot(df.area, reg.predict(df[['area']]), color = 'blue')
#
# NameError: name 'reg' is not defined

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']].values, df.price) #training
# Out:
# LinearRegression()

# %%
m = reg.coef_ #value for m

# %%
b = reg.intercept_ #value for b

# %%
x = 3500
y = m*x+b

# %%
y
# Out:
# array([655873.28767123])

# %%
reg.predict([[3500]])
# Out:
# array([655873.28767123])

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
import pickle

# %%
with open('pickle_model', 'wb') as f:
    pickle.dump(reg, f)
